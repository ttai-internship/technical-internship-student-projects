# %% [markdown]
# # B0：Python 基础起步 Notebook
#
# 这是初级路线的共同基础门。请先运行完整示例，再修改 starter 中的一处代码，最后把自己的测试和证据写回项目。Notebook 负责引导和记录，不替代 src/ 中的工程代码。

# %% [markdown]
# ## Setup
#
# 先确认项目目录和运行入口。不要伪造输出；如果命令失败，把错误和尝试写入记录。

# %%
from pathlib import Path
import sys

CURRENT = Path.cwd().resolve()
REPO_ROOT = next(
    candidate
    for candidate in (CURRENT, *CURRENT.parents)
    if (candidate / "config" / "projects.json").is_file()
)
PROJECT_ROOT = REPO_ROOT / "foundation" / "starter"
sys.path.insert(0, str(PROJECT_ROOT / "src"))
print("project:", PROJECT_ROOT)
assert (PROJECT_ROOT / "src").is_dir()

# %% [markdown]
# ## B0-01：Predict → Run → Modify
#
# 先预测 greeting("Ada") 的结果，再运行。然后修改 lesson01.py 的问候语，并重新运行。

# %%
from foundation_lab.lesson01 import greeting

assert greeting("Ada") == "Hello, Ada!"
print(greeting("Ada"))

# %% [markdown]
# ## B0-02：变量、输入和计算
#
# 解释 price、quantity 和 total 各自保存什么值。修改一个价格和数量，并在 tests/test_public.py 中增加一个断言。

# %%
from foundation_lab.lesson02 import receipt, total_price

assert total_price(2.5, 4) == 10.0
print(receipt("pen", 1.2, 3))

# %% [markdown]
# ## B0-03：条件、循环和列表
#
# 预测 90、60、59 分的分类结果，并解释 sum_numbers 如何逐个处理列表元素。再增加一个空列表或单元素列表案例。

# %%
from foundation_lab.lesson03 import classify_score, sum_numbers

assert [classify_score(score) for score in (90, 60, 59)] == ["excellent", "pass", "retry"]
assert sum_numbers([]) == 0
print(sum_numbers([1, 2, 3]))

# %% [markdown]
# ## B0-04：函数和测试
#
# 指出 lesson04 中的参数、返回值和局部变量。修改一个参数，补充一个断言，并记录一次失败断言和修复过程。

# %%
from foundation_lab.lesson04 import describe_count, repeat_message

assert repeat_message("go", 0) == []
assert repeat_message("go", 3) == ["go", "go", "go"]
assert describe_count(["a", "b"]) == "count=2"
print("function checks passed")

# %% [markdown]
# ## B0-05：Git 和 CI 证据
#
# 完成两个有意义的 commit：一个修改 lesson，一个增加测试。把分支、commit、测试命令、CI 链接和一个错误定位记录写入提交材料。

# %%
evidence = {
    "branch": "",
    "feature_commit": "",
    "test_commit": "",
    "test_command": "uv run --locked python scripts/run_public_tests.py --project B00",
    "ci_url": "",
    "first_error_and_fix": "",
}
print(evidence)
