# %% [markdown]
# # A01：Tool Agent——学生引导 Notebook
#
# ## Goal
#
# 构建一个有工具边界、结构化调用、失败处理和步数上限的 Agent 循环。
#
# 这是学生版引导材料。它提供问题拆解、检查点和证据模板，不提供完整实现答案。最终逻辑必须回写到项目 `src/`，测试必须回写到 `tests/`。

# %% [markdown]
# ## Setup
#
# 先确认你能定位项目根目录、运行 starter，并记录当前 baseline。不要在这一阶段修改 Notebook 中的路径或手工伪造结果。

# %%
from pathlib import Path
import sys

CURRENT = Path.cwd().resolve()
if (CURRENT / "src").is_dir():
    PROJECT_ROOT = CURRENT
else:
    PROJECT_ROOT = next(
        (
            candidate / "starter-projects/advanced/A01-tool-agent"
            for candidate in (CURRENT, *CURRENT.parents)
            if (candidate / "config" / "projects.json").is_file()
        ),
        CURRENT,
    )
assert (PROJECT_ROOT / "src").is_dir(), PROJECT_ROOT
sys.path.insert(0, str(PROJECT_ROOT / "src"))
print("project:", PROJECT_ROOT)
print("files:", sorted(path.name for path in PROJECT_ROOT.iterdir()))

# %% [markdown]
# ## 1. Baseline and contract
#
# 先记录当前 starter 的输入、输出、错误行为和已知限制。

# %%
contract_notes = {
    "normal_input": "填写一个最小正常输入",
    "expected_output": "填写可以观察到的输出",
    "failure_case": "填写一个必须明确处理的失败场景",
    "baseline_limit": "填写当前 starter 的一个限制",
}
print(contract_notes)
print("public test command: python -m unittest discover -s tests -v")

# %% [markdown]
# ## 2. Guided implementation
#
# 下面的步骤只定义实现方向。每完成一项，先在 `src/` 中实现，再用最小测试锁定行为。
#
# 1. 先定义工具名称、参数、返回值和错误格式。
# 2. 将模型决策、工具执行和最终回答分成可测试的边界。
# 3. 为非法工具、非法参数、超时和循环调用设计退出策略。
# 4. 运行 eval/cases.json 的固定案例，并把成功、失败、降级和限制写入报告。

# %%
implementation_evidence = {
    "changed_source_files": [],
    "new_tests": [],
    "observed_failure": "",
    "fix_explanation": "",
}
print(implementation_evidence)

# %% [markdown]
# ## 3. Checks
#
# 为什么 Agent 必须有最大步数和可观察 trace？
#
# 至少补充一个正常场景、一个边界场景和一个失败场景的测试。

# %%
required_paths = [PROJECT_ROOT / "src", PROJECT_ROOT / "tests"]
for required_path in required_paths:
    assert required_path.is_dir(), required_path
print("required project paths are present")

# %% [markdown]
# ## 4. Evidence and next steps
#
# 提交前记录 baseline commit、实现 commit、测试命令、测试结果、Notebook 观察和一个仍然存在的限制。截图只能辅助说明，不能替代代码、测试和现场解释。

# %%
evidence = {
    "baseline_commit": "",
    "implementation_commit": "",
    "test_result": "",
    "notebook_observation": "",
    "known_limitation": "",
}
print(evidence)
